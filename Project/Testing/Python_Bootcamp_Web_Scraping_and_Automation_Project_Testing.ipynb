# %%
# Importing Libraries
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

# %%
# Fetching Data from Website 
a = [0, 60, 120, 180, 240, 300, 360, 420, 480, 540]
for i in a:
  url = f'https://sofifa.com/?offset={i}'
  response = requests.get(url)
  #print(response.status_code)
  soup = BeautifulSoup(response.content, 'lxml')
  print(soup.prettify())
# Out:
# Streaming output truncated to the last 5000 lines.
#             22
#            </td>
#            <td class="col col-oa" data-col="oa">
#             <span class="bp3-tag p p-89">
#              89
#             </span>
#            </td>
#            <td class="col col-pt" data-col="pt">
#             <span class="bp3-tag p p-93">
#              93
#             </span>
#            </td>
#            <td class="col-name">
#             <div class="bp3-text-overflow-ellipsis">
#              <figure class="avatar avatar-sm transparent">
#               <img alt="" class="team" data-root="https://cdn.sofifa.com/teams/" data-src="https://cdn.sofifa.com/teams/73/30.png" data-srcset="https://cdn.sofifa.com/teams/73/60.png 2x, https://cdn.sofifa.com/teams/73/90.png 3x" data-type="team" src="https://cdn.sofifa.com/teams/notfound_30.png"/>
#              </figure>
#              <a href="/team/73/paris-saint-germain/">
#               Paris Saint-Germain
#              </a>
# ...

# %%
# Parameters Decleration
NAME = []
AGE = []
OVA = []
POT = []
TEAM_NAME = []
CONTRACT = []
VALUE = []
WAGE = []
TOTAL = []

# %%
# Testing on a Single Webpage
url = 'https://sofifa.com/?offset=0'
data = []
response = requests.get(url)
#print(response.status_code)
soup = BeautifulSoup(response.content, 'lxml')
#print(soup.prettify())
for i in soup.findAll('td'):
  data.append(str(i))
data
# Out:
# ['<td class="col-avatar" data-balloon="Click here!" data-balloon-pos="up" data-balloon-visible=""><figure class="avatar">\n<img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/235/454/22_60.png" data-srcset="https://cdn.sofifa.com/players/235/454/22_120.png 2x, https://cdn.sofifa.com/players/235/454/22_180.png 3x" data-type="player" id="235454" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure></td>',
# ...

# %%
len(data)
# Out:
# 540

# %%
# Testing
a = 0
for i in range(0,540):
  print(data[i])
  
  a = a + 1

print(a)
# Out:
# <td class="col-avatar" data-balloon="Click here!" data-balloon-pos="up" data-balloon-visible=""><figure class="avatar">
# <img alt="" class="player-check" data-root="https://cdn.sofifa.com/players/" data-src="https://cdn.sofifa.com/players/235/454/22_60.png" data-srcset="https://cdn.sofifa.com/players/235/454/22_120.png 2x, https://cdn.sofifa.com/players/235/454/22_180.png 3x" data-type="player" id="235454" src="https://cdn.sofifa.com/players/notfound_0_60.png"/></figure></td>
# <td class="col-name">
# ...

# %%
# Testing
a = 0
for i in range(0,540):
  temp = (re.sub('<a class="tooltip".*-ellipsis">|<td class=.*">|€|<td class="col-name">|<img alt=.*/></figure>|<div class=.*transparent">|<img alt="".*png"/>|<a href=.*/">|</a><div class="sub">|</figure>|</td>|</span>|</div>|</a><img alt="".*</a>|<div.*|<figure.*|<span class.*On Loan','',data[i])).strip()
  print(temp)
  a = a + 1

print(a)
# Out:
# M. Sarr
# 22
# 74
# 78
# Chelsea
# 2020 ~ 2025
# 5.5M
# 56K
# 1886
#
# É. Mendy
# 29
# 83
# 85
# Chelsea
# 2020 ~ 2025
# 30M
# 105K
# 1168
#
# P. Daka
# 22
# 77
# 84
# Leicester City
# 2021 ~ 2026
# 21.5M
# 78K
# 1848
#
# J. Timber
# 20
# 77
# 87
# Ajax
# 2019 ~ 2024
# 21.5M
# 11K
# 1912
#
# F. Wirtz
# 18
# 79
# 90
# Bayer 04 Leverkusen
# 2020 ~ 2026
# 37M
# 19K
# 1947
#
# C. De Ketelaere
# 20
# 76
# 86
# Club Brugge KV
# 2018 ~ 2024
# 16.5M
# 20K
# 2016
#
# A. Spörle
# 25
# 64
# 66
# Dundee United
# 2019 ~ 2022
# 675K
# 2K
# 1727
#
# D. Kamada
# 24
# 79
# 82
# Eintracht Frankfurt
# 2017 ~ 2023
# 24M
# 29K
# 1924
#
# D. Maldini
# 19
# 59
# 77
# AC Milan
# 2018 ~ 2024
# 575K
# 3K
# 1575
#
# Cristiano Ronaldo
# 36
# 91
# 91
# Manchester United
# 2021 ~ 2023
# 45M
# 270K
# 2207
#
# J. Bellingham
# 18
# 79
# 89
# Borussia Dortmund
# 2020 ~ 2025
# 37M
# 21K
# 2077
#
# Lucas Paquetá
# 23
# 81
# 86
# Olympique Lyonnais
# 2020 ~ 2025
# 39M
# 65K
# 2196
#
# M. Salah
# 29
# 89
# 89
# ...

# %%
# Testing : Scraping Names from Webpage
for i in range(1,541,9):
  temp = (re.sub('<a class="tooltip" data-tooltip=.*<div class="bp3-text-overflow-ellipsis">|</div></a><img.*</span></a></td>|<td class="col-name">','',data[i])).strip()
  print(temp)
# Out:
# M. Sarr
# É. Mendy
# P. Daka
# J. Timber
# F. Wirtz
# C. De Ketelaere
# A. Spörle
# D. Kamada
# D. Maldini
# Cristiano Ronaldo
# J. Bellingham
# Lucas Paquetá
# M. Salah
# Antony
# E. Haaland
# Gavi
# N. Madueke
# K. Adeyemi
# M. Greenwood
# A. Tchouaméni
# Pedri
# R. Gravenberch
# M. Lacroix
# J. Gvardiol
# B. Brereton Díaz
# Raphinha
# N. Lang
# L. Messi
# A. Hložek
# F. Chiesa
# R. Cherki
# Pedro Benito
# Y. Tielemans
# Ansu Fati
# J. Musiala
# D. Vlahović
# Yeremy Pino
# E. Camavinga
# K. Mitoma
# K. Mbappé
# J. Sancho
# G. Raspadori
# A. Bastoni
# A. Davies
# D. Scarlett
# P. Foden
# J. Koundé
# T. Hernández
# A. Broja
# H. Elliott
# F. Kessié
# A. Isak
# S. Tonali
# Nuno Mendes
# J. Doku
# S. Dest
# M. Vandevoordt
# J. David
# Ferran Torres
# Gonçalo Inácio

# %%
# Testing : Scraping Age from Webpage
a = 0
for i in range(2,541,9):
  temp = re.sub('<td class.*"ae">|</td>','',data[i])
  print(temp)
  a = a + 1
print(a)
# Out:
# 22
# 29
# 22
# 20
# 18
# 20
# 25
# 24
# 19
# 36
# 18
# 23
# 29
# 21
# 20
# 16
# 19
# 19
# 19
# 21
# 18
# 19
# 21
# 19
# 22
# 24
# 22
# 34
# 18
# 23
# 17
# 21
# 24
# 18
# 18
# 21
# 18
# 18
# 24
# 22
# 21
# 21
# 22
# 20
# 17
# 21
# 22
# 23
# 19
# 18
# 24
# 21
# 21
# 19
# 19
# 20
# 19
# 21
# 21
# 19
# 60

# %%
# Testing : Scraping Overall Rating from Webpage
a = 0
for i in range(3,541,9):
  temp = re.sub('<td class.*">|</span></td>','',data[i])
  print(temp)
  a = a + 1
a
# Out:
# 74
# 83
# 77
# 77
# 79
# 76
# 64
# 79
# 59
# 91
# 79
# 81
# 89
# 80
# 88
# 68
# 77
# 72
# 78
# 79
# 81
# 78
# 79
# 75
# 73
# 82
# 78
# 93
# 76
# 83
# 73
# 60
# 84
# 76
# 76
# 78
# 74
# 78
# 73
# 91
# 87
# 74
# 80
# 82
# 63
# 84
# 83
# 84
# 70
# 73
# 84
# 82
# 77
# 78
# 77
# 76
# 71
# 78
# 82
# 76
# 60

# %%
# Testing : Scraping Potential from Webpage
a = 0
for i in range(4,541,9):
  temp = re.sub('<td class.*">|</span></td>','',data[i])
  print(temp)
  a = a + 1
a
# Out:
# 78
# 85
# 84
# 87
# 90
# 86
# 66
# 82
# 77
# 91
# 89
# 86
# 89
# 88
# 93
# 85
# 88
# 86
# 89
# 86
# 91
# 90
# 86
# 87
# 80
# 87
# 85
# 93
# 87
# 91
# 88
# 69
# 87
# 90
# 88
# 85
# 85
# 89
# 78
# 95
# 91
# 88
# 88
# 89
# 86
# 92
# 89
# 90
# 84
# 87
# 86
# 86
# 86
# 88
# 87
# 85
# 87
# 86
# 90
# 86
# 60

# %%
# Testing : Scraping Team Name from Webpage
a = 0
for i in range(5,541,9):
  temp = (re.sub('<td class="col-name">|<div class=.*transparent">|<img alt=.*.png"/>|</figure>|<a href="/.*/">|</a><div class="sub">|</div>|</td>|20.*','',data[i])).strip()
  print(temp)
  a = a + 1
a
# Out:
# Chelsea
# Chelsea
# Leicester City
# Ajax
# Bayer 04 Leverkusen
# Club Brugge KV
# Dundee United
# Eintracht Frankfurt
# AC Milan
# Manchester United
# Borussia Dortmund
# Olympique Lyonnais
# Liverpool
# Ajax
# Borussia Dortmund
# FC Barcelona
# PSV
# FC Red Bull Salzburg
# Manchester United
# AS Monaco
# FC Barcelona
# Ajax
# VfL Wolfsburg
# RB Leipzig
# Blackburn Rovers
# Leeds United
# Club Brugge KV
# Paris Saint-Germain
# AC Sparta Praha
# Juventus
# Jun 1,
# Olympique Lyonnais
# Cádiz CF
# Leicester City
# FC Barcelona
# FC Bayern München
# Fiorentina
# Villarreal CF
# Real Madrid CF
# Royale Union Saint-Gilloise
# Jun 30,
# Paris Saint-Germain
# Manchester United
# U.S. Sassuolo Calcio
# Inter
# FC Bayern München
# Tottenham Hotspur
# Manchester City
# Sevilla FC
# AC Milan
# Southampton
# Jun 30,
# Liverpool
# AC Milan
# Real Sociedad
# AC Milan
# Paris Saint-Germain
# Jun 30,
# Stade Rennais FC
# FC Barcelona
# KRC Genk
# LOSC Lille
# Manchester City
# Sporting CP
# 60

# %%
# Scraping Contract from Webpage
a = 0
for i in range(5,541,9):
  temp = (re.sub('<td class="col-name">|<div class=.*transparent">|<img alt=.*.png"/>|</figure>|<a href="/.*<div class="sub">|</div>|</td>|<span class=.*</span>','',data[i])).strip()
  print(temp)
  a = a + 1
a
# Out:
# 2020 ~ 2025
# 2020 ~ 2025
# 2021 ~ 2026
# 2019 ~ 2024
# 2020 ~ 2026
# 2018 ~ 2024
# 2019 ~ 2022
# 2017 ~ 2023
# 2018 ~ 2024
# 2021 ~ 2023
# 2020 ~ 2025
# 2020 ~ 2025
# 2017 ~ 2023
# 2020 ~ 2025
# 2020 ~ 2024
# 2020 ~ 2023
# 2019 ~ 2025
# 2018 ~ 2024
# 2018 ~ 2025
# 2020 ~ 2024
# 2020 ~ 2022
# 2018 ~ 2023
# 2020 ~ 2025
# 2021 ~ 2026
# 2019 ~ 2022
# 2020 ~ 2024
# 2021 ~ 2025
# 2021 ~ 2023
# 2019 ~ 2024
# Jun 1, 2022
# 2019 ~ 2023
# 2021 ~ 2023
# 2019 ~ 2023
# 2018 ~ 2022
# 2020 ~ 2026
# 2018 ~ 2023
# 2020 ~ 2024
# 2021 ~ 2027
# Jun 30, 2022
# 2018 ~ 2022
# 2021 ~ 2026
# 2019 ~ 2022
# 2017 ~ 2024
# 2019 ~ 2025
# 2020 ~ 2023
# 2016 ~ 2024
# 2019 ~ 2024
# 2019 ~ 2024
# Jun 30, 2022
# 2019 ~ 2025
# 2019 ~ 2022
# 2019 ~ 2026
# 2021 ~ 2026
# Jun 30, 2022
# 2020 ~ 2025
# 2020 ~ 2025
# 2018 ~ 2023
# 2020 ~ 2025
# 2020 ~ 2025
# 2019 ~ 2025
# 60

# %%
# Scraping Value(in M) of the Players from Webpage
a = 0
for i in range(6,541,9):
  #print(data[i])
  temp = (re.sub('<td class=.*"vl">€|</td>|M','',data[i])).strip()
  if('K' in temp):
    temp = temp.replace('K','')
    temp = str(float(temp)/1000)
  print(temp)
  a = a + 1
a
# Out:
# 5.5
# 30
# 21.5
# 21.5
# 37
# 16.5
# 0.675
# 24
# 0.575
# 45
# 37
# 39
# 101
# 47.5
# 137.5
# 3
# 23
# 5.5
# 30.5
# 35.5
# 54
# 33
# 33
# 12.5
# 6
# 46
# 28.5
# 78
# 16
# 80.5
# 7
# 0.55
# 57
# 17.5
# 17.5
# 29
# 9
# 29.5
# 4.6
# 194
# 116.5
# 10.5
# 44.5
# 57
# 1.5
# 94.5
# 53
# 62.5
# 3.8
# 7
# 49.5
# 45
# 22.5
# 29
# 23
# 15.5
# 4.3
# 32
# 68.5
# 15
# 60

# %%
# Scraping Wage(in K) from Webpage
a = 0
for i in range(7,541,9):
  #print(data[i])
  temp = (re.sub('<td class=.*"wg">€|</td>','',data[i])).strip()
  if('K' in temp):
    temp = temp.replace('K','')
  else:
    temp = str(float(temp)/1000)
  print(temp)
  a = a + 1
a
# Out:
# 56
# 105
# 78
# 11
# 19
# 20
# 2
# 29
# 3
# 270
# 21
# 65
# 270
# 18
# 110
# 5
# 11
# 13
# 56
# 41
# 51
# 11
# 42
# 27
# 33
# 89
# 27
# 320
# 0.5
# 74
# 9
# 4
# 125
# 44
# 20
# 43
# 9
# 44
# 40
# 230
# 150
# 22
# 77
# 59
# 3
# 125
# 33
# 51
# 29
# 29
# 51
# 37
# 25
# 8
# 29
# 67
# 3
# 31
# 120
# 7
# 60

# %%
# Scraping Total Stats from Webpage
a = 0
for i in range(8,541,9):
  #print(data[i])
  temp = (re.sub('<td class=.*p">|</span></td>','',data[i])).strip()
  print(temp)
  a = a + 1
a
# Out:
# 1886
# 1168
# 1848
# 1912
# 1947
# 2016
# 1727
# 1924
# 1575
# 2207
# 2077
# 2196
# 2211
# 1961
# 2102
# 1735
# 1897
# 1851
# 1955
# 2093
# 2023
# 2074
# 1742
# 1966
# 1827
# 2100
# 2013
# 2219
# 1909
# 2052
# 1712
# 1480
# 2187
# 1814
# 1736
# 1779
# 1709
# 2089
# 1865
# 2175
# 2007
# 1764
# 1801
# 2115
# 1502
# 2060
# 1914
# 2185
# 1663
# 1687
# 2196
# 1910
# 2082
# 2009
# 1810
# 1974
# 1071
# 1862
# 1995
# 1676
# 60
